# %%
import glob

def list_all_files_recursive(directory):
    return glob.glob(f"{directory}/**/*", recursive=True)

list_all_files_recursive("./")
# Out:
# ['./NeMo-Framework-Launcher',
#  './run_dev.ipynb',
#  './NeMo',
#  './train_def_1024_c4_2.py',
#  './train_def_1024_c4_3.py',
#  './data',
#  './preprocess_c4_save.py',
#  './train_dev.py',
#  './nemo_run',
#  './run.ipynb',
#  './NeMo-Run',
#  './train_def_1024_c4.py',
#  './train_def_1024.py',
#  './test.ipynb',
#  './run.py',
#  './train_def_1024_c4_1.py',
#  './NeMo-Framework-Launcher/Dockerfile',
#  './NeMo-Framework-Launcher/LICENSE',
#  './NeMo-Framework-Launcher/auto_configurator',
#  './NeMo-Framework-Launcher/requirements.txt',
#  './NeMo-Framework-Launcher/launcher_scripts',
#  './NeMo-Framework-Launcher/README.md',
#  './NeMo-Framework-Launcher/img',
#  './NeMo-Framework-Launcher/csp_tools',
#  './NeMo-Framework-Launcher/examples',
#  './NeMo-Framework-Launcher/setup.cfg',
#  './NeMo-Framework-Launcher/auto_configurator/tuning',
#  './NeMo-Framework-Launcher/auto_configurator/main.py',
#  './NeMo-Framework-Launcher/auto_configurator/tests',
# ...

# %%
f"""singularity exec --nv \
--bind /net/storage/pr3/plgrid/plggllmeffi/plgmstefaniak/nemo_cementary/nemo_2.0_training_experiment/{123}/training:/nemo_run \
--pwd /nemo_run/code \
/net/storage/pr3/plgrid/plggllmeffi/plgmstefaniak/images/nemo_dev.sif \
bash"""
# Out:
# 'singularity exec --nv --bind /net/storage/pr3/plgrid/plggllmeffi/plgmstefaniak/nemo_cementary/nemo_2.0_training_experiment/123/training:/nemo_run --pwd /nemo_run/code /net/storage/pr3/plgrid/plggllmeffi/plgmstefaniak/images/nemo_dev.sif bash'
